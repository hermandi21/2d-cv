# %% [markdown]
# # 1.1 Bild einladen
# # 1.3 Datentyp auslesen

# %%
from skimage import io
import matplotlib.pyplot as plt

# Bild einlesen
image = io.imread("/home/hermandi21/Mein-Schreibtisch/AIN6/2d-cv/aufgabe01/assets/bild01.jpg")  # Ersetze mit deinem Bildpfad

# Datentyp ausgeben
print("Datentyp des Bildarrays:", image.dtype)

# Form des Arrays ausgeben
print("Shape des Arrays:", image.shape)

# Bild anzeigen
plt.imshow(image)
plt.axis("off")  # Achsen ausblenden
plt.show()
# Out:
# Datentyp des Bildarrays: uint8
# Shape des Arrays: (333, 500, 3)
